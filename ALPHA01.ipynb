# %%
import pandas as pd

# Load your dataset - change filename as needed
data = pd.read_csv('50_Startups.csv')
df = data.copy()

# %%
# Auto-detect target: use common target names if present, else last column
common_targets = ['Exited', 'Profit', 'Purchased', 'Target', 'Class', 'Label', 'y']
target_col = None
for name in common_targets:
    if name in df.columns:
        target_col = name
        break
if target_col is None:
    target_col = df.columns[-1]  # fallback: last column

y = df[target_col]

# ID-like columns to drop (only if they exist in this dataset)
id_patterns = ['RowNumber', 'CustomerId', 'Surname', 'CustomerID', 'Id', 'ID', 'index']
id_columns = [c for c in id_patterns if c in df.columns]

# Features: all columns except target and ID columns
drop_cols = [target_col] + id_columns
X = df.drop(columns=[c for c in drop_cols if c in df.columns], axis=1)

print(f"Target: {target_col}")
print(f"Features ({X.shape[1]}): {list(X.columns)}")
print(f"Dropped (IDs): {id_columns if id_columns else 'none'}")
